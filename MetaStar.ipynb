# %% [markdown]
# #### Importando libs

# %%
import pandas as pd

# %%
CSV_INPUT_FILE = 'votacao_candidato_munzona_2022_BRASIL.csv'

# %%
df = pd.read_csv(filepath_or_buffer=CSV_INPUT_FILE,sep=';',encoding='ISO-8859-1',usecols=['NR_TURNO','DS_ELEICAO',
                                                                    'TP_ABRANGENCIA','SG_UF','NM_MUNICIPIO','NR_ZONA',
                                                                    'DS_CARGO','NR_CANDIDATO','NM_CANDIDATO','NM_URNA_CANDIDATO',
                                                                    'DS_SITUACAO_CANDIDATURA','NR_PARTIDO','SG_PARTIDO','NM_PARTIDO',
                                                                    'NM_COLIGACAO','DS_COMPOSICAO_COLIGACAO','ST_VOTO_EM_TRANSITO','QT_VOTOS_NOMINAIS',
                                                                    'NM_TIPO_DESTINACAO_VOTOS','QT_VOTOS_NOMINAIS_VALIDOS','DS_SIT_TOT_TURNO'])

# %%
df.to_parquet(path='votacao.parquet.gzip',compression='gzip')
pd.read_parquet('votacao.parquet.gzip')
# Out:
#          NR_TURNO                      DS_ELEICAO TP_ABRANGENCIA SG_UF  \
# 0               1  Eleições Gerais Estaduais 2022              E    MG
# 1               1  Eleições Gerais Estaduais 2022              E    RJ
# 2               1  Eleições Gerais Estaduais 2022              E    SP
# 3               1  Eleições Gerais Estaduais 2022              E    SP
# 4               1  Eleições Gerais Estaduais 2022              E    RS
# ...           ...                             ...            ...   ...
# 9379561         1  Eleições Gerais Estaduais 2022              E    SP
# 9379562         1  Eleições Gerais Estaduais 2022              E    SP
# 9379563         1  Eleições Gerais Estaduais 2022              E    RS
# 9379564         1  Eleições Gerais Estaduais 2022              E    RS
# 9379565         1  Eleições Gerais Estaduais 2022              E    PE
#
#                     NM_MUNICIPIO  NR_ZONA           DS_CARGO  NR_CANDIDATO  \
# 0                 CÔNEGO MARINHO      148   Deputado Federal          3080
# 1                  NOVA FRIBURGO       26  Deputado Estadual         55588
# 2                       MIRACATU      218   Deputado Federal          4008
# 3                      CHAVANTES      313  Deputado Estadual         50050
# 4           DILERMANDO DE AGUIAR       81   Deputado Federal          2023
# ...                          ...      ...                ...           ...
# 9379561  SANTO ANTÔNIO DO JARDIM       91   Deputado Federal          3369
# 9379562          SANTA FÉ DO SUL      187   Deputado Federal          4590
# 9379563             MORRO REUTER      153  Deputado Estadual         50800
# 9379564           COQUEIRO BAIXO      104   Deputado Federal          7079
# 9379565                MIRANDIBA       69  Deputado Estadual         22380
#
#                                NM_CANDIDATO      NM_URNA_CANDIDATO  ...  \
# 0                    MARÇAL SERAFIM CÂNDIDO       PROFESSOR MARÇAL  ...
# 1        RICARDO DEMETRIO FERREIRA PIMENTEL   DR. RICARDO PIMENTEL  ...
# 2               PAULO JOSÉ RIBEIRO DA SILVA  CORONEL PAULO RIBEIRO  ...
# 3                                  INÊS PAZ               INÊS PAZ  ...
# 4                  TATIANA RHEINGANTZ ARMOS          TATIANA ARMOS  ...
# ...                                     ...                    ...  ...
# 9379561        FRANCISCO JOSÉ DA CRUZ FILHO         FRANCISCO JOSÉ  ...
# 9379562     ERIKA FERNANDA MATOS DOS SANTOS            ERIKA MATOS  ...
# 9379563                 LUANA SILVA DA ROSA             LUANA ROSA  ...
# 9379564             RAFAEL MOROSINI MIRANDA           RAFAEL CHULÉ  ...
# 9379565              MARIO PEREIRA DA SILVA                MARINHO  ...
#
#         NR_PARTIDO  SG_PARTIDO                               NM_PARTIDO  \
# 0               30        NOVO                             Partido Novo
# 1               55         PSD               Partido Social Democrático
# 2               40         PSB            Partido Socialista Brasileiro
# 3               50        PSOL           Partido Socialismo e Liberdade
# 4               20         PSC                   Partido Social Cristão
# ...            ...         ...                                      ...
# 9379561         33         PMN          Partido da Mobilização Nacional
# 9379562         45        PSDB  Partido da Social Democracia Brasileira
# 9379563         50        PSOL           Partido Socialismo e Liberdade
# 9379564         70      AVANTE                                   AVANTE
# 9379565         22          PL                          Partido Liberal
#
#             NM_COLIGACAO DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  \
# 0        PARTIDO ISOLADO                    NOVO                   N
# 1        PARTIDO ISOLADO                     PSD                   N
# 2        PARTIDO ISOLADO                     PSB                   N
# 3              FEDERAÇÃO             REDE / PSOL                   N
# 4        PARTIDO ISOLADO                     PSC                   N
# ...                  ...                     ...                 ...
# 9379561  PARTIDO ISOLADO                     PMN                   N
# 9379562        FEDERAÇÃO        CIDADANIA / PSDB                   N
# 9379563        FEDERAÇÃO             REDE / PSOL                   N
# 9379564  PARTIDO ISOLADO                  AVANTE                   N
# 9379565  PARTIDO ISOLADO                      PL                   N
#
#         QT_VOTOS_NOMINAIS  NM_TIPO_DESTINACAO_VOTOS QT_VOTOS_NOMINAIS_VALIDOS  \
# 0                       0                    Válido                         0
# 1                       6                    Válido                         6
# 2                       0                    Válido                         0
# 3                       0                    Válido                         0
# 4                       0                    Válido                         0
# ...                   ...                       ...                       ...
# 9379561                 0                    Válido                         0
# 9379562                 0                   Anulado                         0
# 9379563                 3                    Válido                         3
# 9379564                 0                    Válido                         0
# 9379565                 4                    Válido                         4
#
#          DS_SIT_TOT_TURNO
# 0              NÃO ELEITO
# 1                SUPLENTE
# 2                SUPLENTE
# 3                SUPLENTE
# 4              NÃO ELEITO
# ...                   ...
# 9379561        NÃO ELEITO
# 9379562        NÃO ELEITO
# 9379563          SUPLENTE
# 9379564        NÃO ELEITO
# 9379565          SUPLENTE
#
# [9379566 rows x 21 columns]
